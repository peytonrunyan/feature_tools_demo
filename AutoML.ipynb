# %% [markdown]
# # Overview
# This notebook is a tutorial on the basic functionality of the automated feature engineering library 'Feature Tools'.

# %% [markdown]
# ### Imports

# %%
#The basics
import pandas as pd
import numpy as np

# %% [markdown]
# ### Utility Functions and Lists (skip to "Feature Tools Time)
# I'm defining a few utility functions to make cleaning our data faster. The purprose of this tutorial is understanding featuretools, so we won't spend too much time worrying about picture perfect cleaning.

# %%
#Fix dates
def fix_dates(x):

    #Import
    import datetime
    now = datetime.datetime.today()

    #Turn string to datetime
    x.date_recorded = pd.to_datetime(x['date_recorded'],format = '%Y-%m-%d')

    #Turn date into how long ago it happened
    x['age'] = x['date_recorded'] - now

    #sklearn doesn't like time. Turn it into an int
    x['age'] = x['age'].dt.days
    
    return x

#remove the columns that we don't want
def drop_stuff(x):
    x = x.drop(to_drop, axis=1)

    return x

#label NaNs
def label_nans(x):
    x.funder.fillna('unknown', inplace=True)
    x.permit.fillna('unknown', inplace=True)
    x.installer.fillna('unknown', inplace=True)
    x.subvillage.fillna('unknown', inplace=True)
    x.scheme_name.fillna('unknown', inplace=True)
    x.public_meeting.fillna('unknown', inplace=True)
    x.scheme_management.fillna('unknown', inplace=True)

    return x

#Clean Data
def clean_data(x):
    x = label_nans(x)
    x = fix_dates(x)
    x = drop_stuff(x)
    
    return x

# %%
#drop categories that are excessive, or drop redundant
to_drop = ['funder', 'installer', 'wpt_name', 'subvillage','region_code',
          'ward', 'scheme_name','payment', 'quantity_group', 'recorded_by',]

#reserved in case I need to drop gps coords
angry_model = ['gps_height','longitude','latitude']

# %% [markdown]
# # Understanding feature tools
# ---
# ---
#
# ## Organizational Structure
# There are 3 key pieces of terminology to understand the structure that feature tools uses.
#
# ### Entities
# An entity is just a table. Each pandas dataframe is an entity.
#
# ### Entity Sets
# This is just a group of entities. If you have three pandas dataframes that you want to use with feature tools then they will all be contained in the same Entity Set.
#
# ### Relationships
# The most import thing to understand for you to get started with feature tools is how relationships function in feature tools.
#
# Relationships are organized as "parent" and "child" relationships. The "parent" and "child" are both dataframes. The relationship between parent and child is a shared feature (column). The parent can only have unique values in the shared feature, while the child can have repeats of values in the shared feature.
#
# This was hard for me to wrap my head around, so I drew a picture.
#
# 'Dog Breeds Dataframe' (Entity 1) and 'Dogs at Park Today Dataframe' (Entity 2) are both entities that are contained in the entity set called 'Entity Set'.
#
# Entity 1. has a list of dog breeds and their (fake) attributes. Entity 2. is a list of observations about dogs at the dog park today.
#
# Each breed is only listed once under the column "Breed" in Entity 1, but breeds may appear multiple times in the "breed" column of Entity 2. That makes Entity 1 the parent and Entity 2 the child for this particular relationship.

# %% [markdown]
# <img src="relationship_diagram_updated.png" />

# %% [markdown]
# # Prepare our data
# ---
# ---
# The data that we're using is from a previous Kaggle competition. The goal of the competition was to take the data provided and predict which wells would be in need of repair. The data is fairly dirty, has lots of different data types, and is great to learn on.
#
# Our first step is to take our dataframe and cut it into a more digestible chunk so that it's easier for us to understand exactly what featuretools is doing

# %%
# Allow us to view up to 500 columns so that we don't deal with the '...'
pd.set_option('display.max_columns', 500)

# Load in our full set of train data
X = pd.read_csv('train_features.csv')

# Use cleaning function
X = clean_data(X)

# features that we want included for instructional purposes
subset = ['id', 'date_recorded', 'num_private', 'basin', 'population', 'public_meeting']

# a dataframe with a random sample of 1000 rows, including only our selected features
practice = X[subset].sample(1000)

# %%
practice.head()
# Out:
#           id date_recorded  num_private                    basin  population  \
# 25129  22688    2011-03-16            0               Lake Nyasa         148
# 33559  60443    2011-07-13            0            Lake Victoria           0
# 7316   62013    2013-01-29            0  Ruvuma / Southern Coast         400
# 32428  32228    2013-03-04            0                  Pangani         120
# 57685  51201    2011-02-26          102              Wami / Ruvu          20
#
#       public_meeting
# 25129           True
# 33559           True
# 7316            True
# 32428           True
# 57685           True

# %%
# What does the data in our sub-sample look like?
for i in range(len(practice.columns)):
    print(practice.columns[i], '\n',practice.dtypes[i],'\nUnique Values: ', practice.nunique()[i], '\n')
# Out:
# id
#  int64
# Unique Values:  1000
#
# date_recorded
#  datetime64[ns]
# Unique Values:  241
#
# num_private
#  int64
# Unique Values:  10
#
# basin
#  object
# Unique Values:  9
#
# population
#  int64
# Unique Values:  148
#
# public_meeting
#  object
# Unique Values:  3

# %% [markdown]
# # Automated feature engineering time!
# ---
# ---

# %%
# Step 1, import featuretools
import featuretools as ft

# %%
# Step 2, create a new entity set
es = ft.EntitySet('Entity Set')

# %%
# Step 3, add our entities
es.entity_from_dataframe(dataframe=practice, # the dataframe that you want to use to construct the entity
                        entity_id='entity_1', # the reference name for this entity when using featuretools
                        index='id' # the feature with unique values to identify each row by
                        )
# Out:
# Entityset: Entity Set
#   Entities:
#     entity_1 [Rows: 1000, Columns: 6]
#   Relationships:
#     No relationships

# %% [markdown]
# # Houston, we have a problem.
# ---
# ---
# We have one 1 entity under Entities, and no relationships. In our example with the dog breeds, we had two dataframes so that we could create a relationship for featuretools to use. We only have a single dataframe to work with, which means only 1 entity.
#
# Luckily, featuretools allows us to create new entities from existing entites using "normalize_entity".
#
# If you look back at our "basin" column, you'll see that it had 9 values. Let's see what happens if we turn "basin" into its own untity using the featuretools "normalize_entity" function.

# %%
# Create a new entity from an existing entity's features

es.normalize_entity(base_entity_id='entity_1', # the entity that has the feature/column that you want to turn into an entity
                   new_entity_id='basins', # the reference name for this new entity when using featuretools
                    index='basin' # the name of the feature that you want to use to construct your new entity
                   )
# Out:
# Entityset: Entity Set
#   Entities:
#     entity_1 [Rows: 1000, Columns: 6]
#     basins [Rows: 9, Columns: 1]
#   Relationships:
#     entity_1.basin -> basins.basin

# %% [markdown]
# # Actually time to do some automated feature engineering!
# ---
# ---
# It will be easier to run the code and look at what featuretools generated before I explain exactly what featuretools is doing. After that, we'll discuss the featuretools approach to feature generation. The only thing that you need to know for this next step is that the target_entity is the entity that we are adding the new features to. It will likely be the dataframe that you will be using to generate predictions with for your model.

# %%
# this is standard syntax for featuretools.
# fm is your dataframe with both the old and newly engineered features
# features is your list of features in fm 
fm, features = ft.dfs(entityset=es,
                     target_entity='entity_1')

# %%
fm.head()
# Out:
#      num_private                    basin  population public_meeting  \
# id
# 5              0              Wami / Ruvu        6922           True
# 102            0          Lake Tanganyika         145           True
# 119            0                   Rufiji           0           True
# 214            0  Ruvuma / Southern Coast         320           True
# 337            0          Lake Tanganyika         450           True
#
#      DAY(date_recorded)  YEAR(date_recorded)  MONTH(date_recorded)  \
# id
# 5                    26                 2011                     2
# 102                  20                 2013                     1
# 119                  15                 2011                     4
# 214                  18                 2013                     1
# 337                  26                 2013                     1
#
#      WEEKDAY(date_recorded)  basins.SUM(entity_1.num_private)  \
# id
# 5                         5                                 0
# 102                       6                                 0
# 119                       4                                 2
# 214                       4                                30
# 337                       5                                 0
#
#      basins.SUM(entity_1.population)  basins.STD(entity_1.num_private)  \
# id
# 5                              29007                          0.000000
# 102                            30669                          0.000000
# 119                            23220                          0.120818
# 214                            17369                          3.692745
# 337                            30669                          0.000000
#
#      basins.STD(entity_1.population)  basins.MAX(entity_1.num_private)  \
# id
# 5                        1017.679601                                 0
# 102                       451.701544                                 0
# 119                       341.077796                                 1
# 214                       484.819922                                30
# 337                       451.701544                                 0
#
#      basins.MAX(entity_1.population)  basins.SKEW(entity_1.num_private)  \
# id
# 5                               6922                           0.000000
# 102                             3200                           0.000000
# 119                             2800                           8.153387
# 214                             3000                           8.124038
# 337                             3200                           0.000000
#
#      basins.SKEW(entity_1.population)  basins.MIN(entity_1.num_private)  \
# id
# 5                            6.147406                                 0
# 102                          4.115083                                 0
# 119                          4.927333                                 0
# 214                          4.444413                                 0
# 337                          4.115083                                 0
#
#      basins.MIN(entity_1.population)  basins.MEAN(entity_1.num_private)  \
# id
# 5                                  0                           0.000000
# 102                                0                           0.000000
# 119                                0                           0.014706
# 214                                0                           0.454545
# 337                                0                           0.000000
#
#      basins.MEAN(entity_1.population)  basins.COUNT(entity_1)  \
# id
# 5                          315.293478                      92
# 102                        262.128205                     117
# 119                        170.735294                     136
# 214                        263.166667                      66
# 337                        262.128205                     117
#
#      basins.NUM_UNIQUE(entity_1.public_meeting)  \
# id
# 5                                             3
# 102                                           3
# 119                                           3
# 214                                           3
# 337                                           3
#
#      basins.MODE(entity_1.public_meeting)
# id
# 5                                    True
# 102                                  True
# 119                                  True
# 214                                  True
# 337                                  True

# %%
features
# Out:
# [<Feature: num_private>,
#  <Feature: basin>,
#  <Feature: population>,
#  <Feature: public_meeting>,
#  <Feature: DAY(date_recorded)>,
#  <Feature: YEAR(date_recorded)>,
#  <Feature: MONTH(date_recorded)>,
#  <Feature: WEEKDAY(date_recorded)>,
#  <Feature: basins.SUM(entity_1.num_private)>,
#  <Feature: basins.SUM(entity_1.population)>,
#  <Feature: basins.STD(entity_1.num_private)>,
#  <Feature: basins.STD(entity_1.population)>,
#  <Feature: basins.MAX(entity_1.num_private)>,
#  <Feature: basins.MAX(entity_1.population)>,
#  <Feature: basins.SKEW(entity_1.num_private)>,
#  <Feature: basins.SKEW(entity_1.population)>,
#  <Feature: basins.MIN(entity_1.num_private)>,
#  <Feature: basins.MIN(entity_1.population)>,
#  <Feature: basins.MEAN(entity_1.num_private)>,
#  <Feature: basins.MEAN(entity_1.population)>,
#  <Feature: basins.COUNT(entity_1)>,
#  <Feature: basins.NUM_UNIQUE(entity_1.public_meeting)>,
#  <Feature: basins.MODE(entity_1.public_meeting)>]

# %% [markdown]
# # So what just happened?
# ---
# ---
# The first thing that we can see is that ft separated our date_recorded feature into DAY, YEAR, MONTH, and WEEKDAY, and then dropped date_recorded. We can see where the new feature was derived from based on what is inside of the parenthesis of the new feature name. For example, DAY(date_recorded).
#
# ### Transformations
# This act of taking one feature and transforming it into a new feature is called, simply enough, "transformation". It is one of the two categories of operations that featuretools refers to as "primatives".
#
# ### Aggregations
# The other primative operation is called an aggregation. An example of an aggregation is basins.SUM(entity_1.num_private). We'll explore this in more depth in the next cells.
#
# If you look below, you'll see 2 pandas groupby objects - a numeric groupby and a categorical groupby. These are aggregations.

# %%
# create groupby object, grouped by basin, for our numeric columns, and show the sum, stddev, max, skew, min, and mean values 
numeric_aggregation = practice.groupby('basin')['num_private','population'].agg(['sum', 'std', 'max', 'skew', 'min', 'mean'])

# create groupby object,grouped by basin, for our categorical columns, and show the number of unique values
# mode for categorical data takes some extra work in pandas, so we're skipping it here 
categorical_aggregation = practice.groupby('basin')['public_meeting'].agg(['nunique'])

# %%
numeric_aggregation
# Out:
#                         num_private                                          \
#                                 sum        std  max      skew min      mean
# basin
# Internal                          0   0.000000    0  0.000000   0  0.000000
# Lake Nyasa                      141  15.666667  141  9.000000   0  1.740741
# Lake Rukwa                        0   0.000000    0  0.000000   0  0.000000
# Lake Tanganyika                   0   0.000000    0  0.000000   0  0.000000
# Lake Victoria                    14   0.654158    6  8.714305   0  0.079545
# Pangani                         153   5.658965   45  6.596660   0  0.962264
# Rufiji                            2   0.120818    1  8.153387   0  0.014706
# Ruvuma / Southern Coast          30   3.692745   30  8.124038   0  0.454545
# Wami / Ruvu                       0   0.000000    0  0.000000   0  0.000000
#
#                         population                                   \
#                                sum          std   max      skew min
# basin
# Internal                     14067   196.647206  1200  2.794165   0
# Lake Nyasa                    3434   100.849849   500  3.125453   0
# Lake Rukwa                    7033   326.131709  1500  3.329905   0
# Lake Tanganyika              30669   451.701544  3200  4.115083   0
# Lake Victoria                42382   862.092403  7500  6.009413   0
# Pangani                      26694   331.313018  3500  6.959303   1
# Rufiji                       23220   341.077796  2800  4.927333   0
# Ruvuma / Southern Coast      17369   484.819922  3000  4.444413   0
# Wami / Ruvu                  29007  1017.679601  6922  6.147406   0
#
#
#                                mean
# basin
# Internal                 109.898438
# Lake Nyasa                42.395062
# Lake Rukwa               156.288889
# Lake Tanganyika          262.128205
# Lake Victoria            240.806818
# Pangani                  167.886792
# Rufiji                   170.735294
# Ruvuma / Southern Coast  263.166667
# Wami / Ruvu              315.293478

# %%
categorical_aggregation
# Out:
#                          nunique
# basin
# Internal                       3
# Lake Nyasa                     3
# Lake Rukwa                     2
# Lake Tanganyika                3
# Lake Victoria                  3
# Pangani                        2
# Rufiji                         3
# Ruvuma / Southern Coast        3
# Wami / Ruvu                    3

# %% [markdown]
# ---
# ---
# Aggregations are bread-and-butter feature engineering operations. Groupby, aggregation, join to the original dataframe. It can get tedious. Featuretools was able to handle it for us.
#
# However, the functions that we've demonstrated so far are only touched the surface of what featuretools can do.

# %%
# Primary Entity

# Additional Entites Made From Primary
es.normalize_entity(base_entity_id='test',
                   new_entity_id='basins',
                    index='basin'
                   )

es.normalize_entity(base_entity_id='test',
                   new_entity_id='lgas',
                    index='lga'
                   )

es.normalize_entity(base_entity_id='test',
                   new_entity_id='extraction_types',
                    index='extraction_type'
                   )
# Out:
# Entityset: Learn Stuff
#   Entities:
#     test [Rows: 59400, Columns: 31]
#     basins [Rows: 9, Columns: 1]
#     lgas [Rows: 125, Columns: 1]
#     extraction_types [Rows: 18, Columns: 1]
#   Relationships:
#     test.basin -> basins.basin
#     test.lga -> lgas.lga
#     test.extraction_type -> extraction_types.extraction_type

# %% [markdown]
# ### fm is our new dataframe

# %%
fm, features = ft.dfs(entityset=es,
                     target_entity='test')

# %% [markdown]
# # Modeling Prep

# %% [markdown]
# ### Prep y

# %%
y = pd.read_csv('train_labels.csv')

#make y values match x values, which are sorted by id
y = y.sort_values('id')
y = y.reset_index()
y = y.drop('index', axis=1)

#status_group is target
y = y.status_group

#encode y to numbers for model
le = LabelEncoder()
le.fit(y)
y = le.transform(y)

# %% [markdown]
# ### Prep X

# %%
X = fm

# %% [markdown]
# ### Split data

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y)

# %% [markdown]
# ### Separate our data into categorical and numeric
# This allows us to to perform PCA on our numeric data and MCA on our categorical data. This is an important distinction, because PCA calculates distance between points, which can't be effectively calculated for categorical data.

# %%
#separate into numeric and categorical
nums = X_train.select_dtypes(include=np.number)
cats = X_train.select_dtypes(include='object')
from sklearn.decomposition import PCA

# %%
#numeric data has a few nans. Add arbitrary value because I'm tired
nums = nums.fillna(1)

# %%
pca = PCA(n_components=50)
pca.fit(nums)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=50, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
num_vals = pca.transform(nums)

# %%
cats.isna().sum().sum()
# Out:
# 0

# %%
cats = cats.astype('category')

# %%
#cats = cats.drop('lgas.MODE(test.permit)', axis=1)
#cats = cats.drop('permit',axis=1)
#cats = cats.drop('lgas.MODE(test.public_meeting)', axis=1)
cats = cats.drop('public_meeting', axis=1)
cats.head()
# Out:
#                  basin     region      lga scheme_management extraction_type  \
# id
# 73006    Lake Victoria  Shinyanga   Kahama           unknown     nira/tanira
# 28772           Rufiji    Singida  Manyoni           unknown         afridev
# 11898    Lake Victoria  Shinyanga   Kahama           unknown     nira/tanira
# 65177    Lake Victoria     Kagera  Karagwe               VWC         gravity
# 54808  Lake Tanganyika     Tabora   Urambo               VWC         afridev
#
#       extraction_type_group extraction_type_class management management_group  \
# id
# 73006           nira/tanira              handpump    unknown          unknown
# 28772               afridev              handpump        vwc       user-group
# 11898           nira/tanira              handpump    unknown          unknown
# 65177               gravity               gravity        vwc       user-group
# 54808               afridev              handpump        vwc       user-group
#
#       payment_type water_quality quality_group quantity        source  \
# id
# 73006      unknown       unknown       unknown  unknown  shallow well
# 28772    never pay          soft          good   enough  shallow well
# 11898      unknown       unknown       unknown  unknown  shallow well
# 65177    never pay          soft          good      dry         river
# 54808    never pay          soft          good   enough   machine dbh
#
#         source_type source_class     waterpoint_type waterpoint_type_group  \
# id
# 73006  shallow well  groundwater           hand pump             hand pump
# 28772  shallow well  groundwater           hand pump             hand pump
# 11898  shallow well  groundwater           hand pump             hand pump
# 65177    river/lake      surface  communal standpipe    communal standpipe
# 54808      borehole  groundwater           hand pump             hand pump
#
#       basins.MODE(test.region) basins.MODE(test.lga)  \
# id
# 73006                   Mwanza               Bariadi
# 28772                   Iringa                Njombe
# 11898                   Mwanza               Bariadi
# 65177                   Mwanza               Bariadi
# 54808                   Kigoma                Kasulu
#
#       basins.MODE(test.scheme_management) basins.MODE(test.extraction_type)  \
# id
# 73006                                 VWC                       nira/tanira
# 28772                                 VWC                           gravity
# 11898                                 VWC                       nira/tanira
# 65177                                 VWC                       nira/tanira
# 54808                                 VWC                           gravity
#
#       basins.MODE(test.extraction_type_group)  \
# id
# 73006                             nira/tanira
# 28772                                 gravity
# 11898                             nira/tanira
# 65177                             nira/tanira
# 54808                                 gravity
#
#       basins.MODE(test.extraction_type_class) basins.MODE(test.management)  \
# id
# 73006                                handpump                          vwc
# 28772                                 gravity                          vwc
# 11898                                handpump                          vwc
# 65177                                handpump                          vwc
# 54808                                 gravity                          vwc
#
#       basins.MODE(test.management_group) basins.MODE(test.payment_type)  \
# id
# 73006                         user-group                      never pay
# 28772                         user-group                      never pay
# 11898                         user-group                      never pay
# 65177                         user-group                      never pay
# 54808                         user-group                        unknown
#
#       basins.MODE(test.water_quality) basins.MODE(test.quality_group)  \
# id
# 73006                            soft                            good
# 28772                            soft                            good
# 11898                            soft                            good
# 65177                            soft                            good
# 54808                            soft                            good
#
#       basins.MODE(test.quantity) basins.MODE(test.source)  \
# id
# 73006                     enough             shallow well
# 28772                     enough                    river
# 11898                     enough             shallow well
# 65177                     enough             shallow well
# 54808                     enough             shallow well
#
#       basins.MODE(test.source_type) basins.MODE(test.source_class)  \
# id
# 73006                  shallow well                    groundwater
# 28772                    river/lake                    groundwater
# 11898                  shallow well                    groundwater
# 65177                  shallow well                    groundwater
# 54808                  shallow well                    groundwater
#
#       basins.MODE(test.waterpoint_type)  \
# id
# 73006                         hand pump
# 28772                communal standpipe
# 11898                         hand pump
# 65177                         hand pump
# 54808                         hand pump
#
#       basins.MODE(test.waterpoint_type_group) lgas.MODE(test.basin)  \
# id
# 73006                               hand pump       Lake Tanganyika
# 28772                      communal standpipe              Internal
# 11898                               hand pump       Lake Tanganyika
# 65177                               hand pump         Lake Victoria
# 54808                      communal standpipe       Lake Tanganyika
#
#       lgas.MODE(test.region) lgas.MODE(test.scheme_management)  \
# id
# 73006              Shinyanga                           unknown
# 28772                Singida                               VWC
# 11898              Shinyanga                           unknown
# 65177                 Kagera                           unknown
# 54808                 Tabora                               VWC
#
#       lgas.MODE(test.extraction_type) lgas.MODE(test.extraction_type_group)  \
# id
# 73006                           other                                 other
# 28772                            mono                                  mono
# 11898                           other                                 other
# 65177                         gravity                               gravity
# 54808                         afridev                               afridev
#
#       lgas.MODE(test.extraction_type_class) lgas.MODE(test.management)  \
# id
# 73006                              handpump                        wug
# 28772                             motorpump                        vwc
# 11898                              handpump                        wug
# 65177                               gravity                        vwc
# 54808                              handpump                        vwc
#
#       lgas.MODE(test.management_group) lgas.MODE(test.payment_type)  \
# id
# 73006                       user-group                      unknown
# 28772                       user-group                    never pay
# 11898                       user-group                      unknown
# 65177                       user-group                    never pay
# 54808                       user-group                    never pay
#
#       lgas.MODE(test.water_quality) lgas.MODE(test.quality_group)  \
# id
# 73006                         milky                         milky
# 28772                          soft                          good
# 11898                         milky                         milky
# 65177                          soft                          good
# 54808                          soft                          good
#
#       lgas.MODE(test.quantity) lgas.MODE(test.source)  \
# id
# 73006                   enough           shallow well
# 28772                   enough            machine dbh
# 11898                   enough           shallow well
# 65177                   enough                 spring
# 54808                   enough           shallow well
#
#       lgas.MODE(test.source_type) lgas.MODE(test.source_class)  \
# id
# 73006                shallow well                  groundwater
# 28772                    borehole                  groundwater
# 11898                shallow well                  groundwater
# 65177                      spring                  groundwater
# 54808                shallow well                  groundwater
#
#       lgas.MODE(test.waterpoint_type) lgas.MODE(test.waterpoint_type_group)  \
# id
# 73006                           other                                 other
# 28772     communal standpipe multiple                    communal standpipe
# 11898                           other                                 other
# 65177              communal standpipe                    communal standpipe
# 54808                       hand pump                             hand pump
#
#       extraction_types.MODE(test.basin) extraction_types.MODE(test.region)  \
# id
# 73006                     Lake Victoria                          Shinyanga
# 28772                     Lake Victoria                             Tabora
# 11898                     Lake Victoria                          Shinyanga
# 65177                           Pangani                             Iringa
# 54808                     Lake Victoria                             Tabora
#
#       extraction_types.MODE(test.lga)  \
# id
# 73006                         Bariadi
# 28772                          Iramba
# 11898                         Bariadi
# 65177                          Njombe
# 54808                          Iramba
#
#       extraction_types.MODE(test.scheme_management)  \
# id
# 73006                                           VWC
# 28772                                           VWC
# 11898                                           VWC
# 65177                                           VWC
# 54808                                           VWC
#
#       extraction_types.MODE(test.extraction_type_group)  \
# id
# 73006                                       nira/tanira
# 28772                                           afridev
# 11898                                       nira/tanira
# 65177                                           gravity
# 54808                                           afridev
#
#       extraction_types.MODE(test.extraction_type_class)  \
# id
# 73006                                          handpump
# 28772                                          handpump
# 11898                                          handpump
# 65177                                           gravity
# 54808                                          handpump
#
#       extraction_types.MODE(test.management)  \
# id
# 73006                                    vwc
# 28772                                    vwc
# 11898                                    vwc
# 65177                                    vwc
# 54808                                    vwc
#
#       extraction_types.MODE(test.management_group)  \
# id
# 73006                                   user-group
# 28772                                   user-group
# 11898                                   user-group
# 65177                                   user-group
# 54808                                   user-group
#
#       extraction_types.MODE(test.payment_type)  \
# id
# 73006                                never pay
# 28772                                never pay
# 11898                                never pay
# 65177                                never pay
# 54808                                never pay
#
#       extraction_types.MODE(test.water_quality)  \
# id
# 73006                                      soft
# 28772                                      soft
# 11898                                      soft
# 65177                                      soft
# 54808                                      soft
#
#       extraction_types.MODE(test.quality_group)  \
# id
# 73006                                      good
# 28772                                      good
# 11898                                      good
# 65177                                      good
# 54808                                      good
#
#       extraction_types.MODE(test.quantity) extraction_types.MODE(test.source)  \
# id
# 73006                               enough                       shallow well
# 28772                               enough                        machine dbh
# 11898                               enough                       shallow well
# 65177                               enough                             spring
# 54808                               enough                        machine dbh
#
#       extraction_types.MODE(test.source_type)  \
# id
# 73006                            shallow well
# 28772                                borehole
# 11898                            shallow well
# 65177                                  spring
# 54808                                borehole
#
#       extraction_types.MODE(test.source_class)  \
# id
# 73006                              groundwater
# 28772                              groundwater
# 11898                              groundwater
# 65177                              groundwater
# 54808                              groundwater
#
#       extraction_types.MODE(test.waterpoint_type)  \
# id
# 73006                                   hand pump
# 28772                                   hand pump
# 11898                                   hand pump
# 65177                          communal standpipe
# 54808                                   hand pump
#
#       extraction_types.MODE(test.waterpoint_type_group)
# id
# 73006                                         hand pump
# 28772                                         hand pump
# 11898                                         hand pump
# 65177                                communal standpipe
# 54808                                         hand pump

# %%
import prince
mca = prince.MCA(
    n_components=20,
    n_iter=3,
    check_input=True,
    engine='auto',
    random_state=42
)

# %%
mca.fit(cats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-169325a89248> in <module>
# ----> 1 mca.fit(cats)
#
# /anaconda3/lib/python3.7/site-packages/prince/mca.py in fit(self, X, y)
#      26
#      27         # Apply CA to the indicator matrix
# ---> 28         super().fit(self.one_hot_.transform(X))
#      29
#      30         # Compute the total inertia
#
# /anaconda3/lib/python3.7/site-packages/prince/ca.py in fit(self, X, y)
#      36
#      37         if isinstance(X, pd.DataFrame):
# ---> 38             X = X.to_numpy()
#      39
#      40         if self.copy:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374                                              copy=copy, allow_dups=False)
#    4375
# -> 4376         return obj
#    4377
#    4378     def _needs_reindex_multi(self, axes, method, level):
#
# AttributeError: 'SparseDataFrame' object has no attribute 'to_numpy'

# %% [markdown]
# # Model

# %%
#identify categories
categorical_features_indices = np.where(X.dtypes != np.float)[0]

#set model
model = CatBoostClassifier(
    random_seed=42
)

# %%
#fit model
model.fit(
    X_train, y_train,
    cat_features=categorical_features_indices,
    eval_set=(X_valid, y_valid),
    logging_level='Verbose'
)

# %%
X.head()
# Out:
#       id  amount_tsh  num_private                    basin   region  \
# 0  69572      6000.0            0               Lake Nyasa   Iringa
# 1   8776         0.0            0            Lake Victoria     Mara
# 2  34310        25.0            0                  Pangani  Manyara
# 3  67743         0.0            0  Ruvuma / Southern Coast   Mtwara
# 4  19728         0.0            0            Lake Victoria   Kagera
#
#    district_code        lga  population public_meeting scheme_management  \
# 0              5     Ludewa         109           True               VWC
# 1              2  Serengeti         280        unknown             Other
# 2              4  Simanjiro         250           True               VWC
# 3             63   Nanyumbu          58           True               VWC
# 4              1    Karagwe           0           True           unknown
#
#   permit             construction_year extraction_type extraction_type_group  \
# 0  False 1970-01-01 00:00:00.000001999         gravity               gravity
# 1   True 1970-01-01 00:00:00.000002010         gravity               gravity
# 2   True 1970-01-01 00:00:00.000002009         gravity               gravity
# 3   True 1970-01-01 00:00:00.000001986     submersible           submersible
# 4   True 1970-01-01 00:00:00.000000000         gravity               gravity
#
#   extraction_type_class management management_group payment_type  \
# 0               gravity        vwc       user-group     annually
# 1               gravity        wug       user-group    never pay
# 2               gravity        vwc       user-group   per bucket
# 3           submersible        vwc       user-group    never pay
# 4               gravity      other            other    never pay
#
#   water_quality quality_group      quantity                source  \
# 0          soft          good        enough                spring
# 1          soft          good  insufficient  rainwater harvesting
# 2          soft          good        enough                   dam
# 3          soft          good           dry           machine dbh
# 4          soft          good      seasonal  rainwater harvesting
#
#             source_type source_class              waterpoint_type  \
# 0                spring  groundwater           communal standpipe
# 1  rainwater harvesting      surface           communal standpipe
# 2                   dam      surface  communal standpipe multiple
# 3              borehole  groundwater  communal standpipe multiple
# 4  rainwater harvesting      surface           communal standpipe
#
#   waterpoint_type_group   age            age_since_built
# 0    communal standpipe -2887 15046 days 23:59:59.999998
# 1    communal standpipe -2164 15769 days 23:59:59.999997
# 2    communal standpipe -2173 15760 days 23:59:59.999997
# 3    communal standpipe -2201 15732 days 23:59:59.999998
# 4    communal standpipe -2766        15168 days 00:00:00

# %% [markdown]
# # Scratch pad

# %%
#construction dictionary of data types
f = ft.variable_types

var_types = {'amount_tsh':ft.variable_types.Numeric, 'num_private':f.Numeric, 'basin':f.Categorical, 'region':f.Categorical,
'district_code':f.Categorical, 'lga':f.Categorical, 'population':f.Numeric, 'public_meeting':f.Categorical, 
'scheme_management':f.Categorical, 'permit':f.Categorical, 'construction_year':f.Datetime, 'extraction_type':f.Categorical,
'extraction_type_group':f.Categorical, 'extraction_type_class':f.Categorical,'management':f.Categorical, 
'management_group':f.Categorical, 'payment_type':f.Categorical, 'water_quality':f.Categorical, 'quality_group':f.Categorical,
'quantity':f.Categorical, 'source':f.Categorical, 'source_type': f.Categorical, 'source_class':f.Categorical, 
'waterpoint_type':f.Categorical, 'waterpoint_type_group':f.Categorical, 'age':f.Numeric
}
